# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
    """
    Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
    it for the linear classifier. These are the same steps as we used for the
    SVM, but condensed to a single function.  
    """
    # Load the raw CIFAR-10 data
    cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
    
    # Cleaning up variables to prevent loading data multiple times (which may cause memory issue)
    try:
       del X_train, y_train
       del X_test, y_test
       print('Clear previously loaded data.')
    except:
       pass

    X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
    
    # subsample the data
    mask = list(range(num_training, num_training + num_validation))
    X_val = X_train[mask]
    y_val = y_train[mask]
    mask = list(range(num_training))
    X_train = X_train[mask]
    y_train = y_train[mask]
    mask = list(range(num_test))
    X_test = X_test[mask]
    y_test = y_test[mask]
    mask = np.random.choice(num_training, num_dev, replace=False)
    X_dev = X_train[mask]
    y_dev = y_train[mask]
    
    # Preprocessing: reshape the image data into rows
    X_train = np.reshape(X_train, (X_train.shape[0], -1))
    X_val = np.reshape(X_val, (X_val.shape[0], -1))
    X_test = np.reshape(X_test, (X_test.shape[0], -1))
    X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
    
    # Normalize the data: subtract the mean image
    mean_image = np.mean(X_train, axis = 0)
    X_train -= mean_image
    X_val -= mean_image
    X_test -= mean_image
    X_dev -= mean_image
    
    # add bias dimension and transform into columns
    X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
    X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
    X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
    X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
    
    return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
print('dev data shape: ', X_dev.shape)
print('dev labels shape: ', y_dev.shape)
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))
# Out:
# loss: 2.319406
# sanity check: 2.302585

# %% [markdown]
# **Inline Question 1**
#
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# $\color{blue}{\textit Your Answer:}$ *Fill this in*

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: -0.072099 analytic: -0.072099, relative error: 2.589787e-07
# numerical: -0.382959 analytic: -0.382959, relative error: 2.169050e-08
# numerical: 1.091533 analytic: 1.091533, relative error: 2.095759e-08
# numerical: 2.904681 analytic: 2.904681, relative error: 8.511926e-09
# numerical: 1.128078 analytic: 1.128078, relative error: 9.065863e-09
# numerical: 0.885601 analytic: 0.885601, relative error: 1.829824e-09
# numerical: 1.693514 analytic: 1.693514, relative error: 7.506262e-09
# numerical: -0.704773 analytic: -0.704773, relative error: 6.893650e-08
# numerical: -0.418559 analytic: -0.418559, relative error: 4.136001e-08
# numerical: 2.349438 analytic: 2.349438, relative error: 2.380225e-08
# numerical: -2.432671 analytic: -2.432672, relative error: 1.474608e-08
# numerical: 2.226358 analytic: 2.226358, relative error: 1.284119e-08
# numerical: -0.614595 analytic: -0.614595, relative error: 2.730514e-08
# numerical: 2.507156 analytic: 2.507156, relative error: 3.350464e-08
# numerical: 1.391918 analytic: 1.391918, relative error: 8.093470e-09
# numerical: -0.563571 analytic: -0.563571, relative error: 2.598458e-08
# numerical: 0.927180 analytic: 0.927180, relative error: 1.713815e-08
# numerical: 1.513065 analytic: 1.513065, relative error: 1.877720e-09
# numerical: -2.977024 analytic: -2.977024, relative error: 5.560896e-10
# numerical: -0.207801 analytic: -0.207801, relative error: 6.132786e-08

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)
# Out:
# naive loss: 2.319406e+00 computed in 0.025907s
# vectorized loss: 2.319406e+00 computed in 0.002995s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
learning_rates =  [1e-7, 5e-5, 2e-8, 3e-7, 8e-8]
regularization_strengths = [2.5e4, 5e4, 1e5, 1e6, 3e3]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
for learning_rate in learning_rates:
    for regularization_strength in regularization_strengths:
        hyper = (learning_rate, regularization_strength)
        linear_softmax = Softmax()
        loss_hist = linear_softmax.train(X_train, y_train, learning_rate=learning_rate, reg=regularization_strength,
                      num_iters=1500, verbose=True)
        y_train_pred = linear_softmax.predict(X_train)
        y_train_acc = np.mean(y_train == y_train_pred)
        #print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
        y_val_pred = linear_softmax.predict(X_val)
        y_val_acc = np.mean(y_val == y_val_pred)
        #print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
        results[hyper] = (y_train_acc, y_val_acc)
        if(y_val_acc > best_val):
            best_val = y_val_acc
            best_softmax = linear_softmax


# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)
# Out:
# iteration 0 / 1500: loss 767.786356
# iteration 100 / 1500: loss 281.737076
# iteration 200 / 1500: loss 104.521763
# iteration 300 / 1500: loss 39.530492
# iteration 400 / 1500: loss 15.845357
# iteration 500 / 1500: loss 7.140768
# iteration 600 / 1500: loss 3.980782
# iteration 700 / 1500: loss 2.780938
# iteration 800 / 1500: loss 2.331825
# iteration 900 / 1500: loss 2.163495
# iteration 1000 / 1500: loss 2.161978
# iteration 1100 / 1500: loss 2.096040
# iteration 1200 / 1500: loss 2.058270
# iteration 1300 / 1500: loss 2.113625
# iteration 1400 / 1500: loss 2.027496
# iteration 0 / 1500: loss 1529.616907
# iteration 100 / 1500: loss 206.241431
# iteration 200 / 1500: loss 29.428492
# iteration 300 / 1500: loss 5.767007
# iteration 400 / 1500: loss 2.610404
# iteration 500 / 1500: loss 2.219256
# iteration 600 / 1500: loss 2.146141
# iteration 700 / 1500: loss 2.109962
# iteration 800 / 1500: loss 2.124723
# iteration 900 / 1500: loss 2.163078
# iteration 1000 / 1500: loss 2.172845
# iteration 1100 / 1500: loss 2.172905
# iteration 1200 / 1500: loss 2.124343
# iteration 1300 / 1500: loss 2.188580
# iteration 1400 / 1500: loss 2.096772
# iteration 0 / 1500: loss 3084.426233
# iteration 100 / 1500: loss 56.193399
# iteration 200 / 1500: loss 3.165799
# iteration 300 / 1500: loss 2.203232
# iteration 400 / 1500: loss 2.204108
# iteration 500 / 1500: loss 2.183402
# iteration 600 / 1500: loss 2.157351
# iteration 700 / 1500: loss 2.197670
# iteration 800 / 1500: loss 2.178103
# iteration 900 / 1500: loss 2.143811
# iteration 1000 / 1500: loss 2.167771
# iteration 1100 / 1500: loss 2.185072
# iteration 1200 / 1500: loss 2.172464
# iteration 1300 / 1500: loss 2.188524
# iteration 1400 / 1500: loss 2.195361
# iteration 0 / 1500: loss 30460.266026
# iteration 100 / 1500: loss 2.289997
# iteration 200 / 1500: loss 2.285448
# iteration 300 / 1500: loss 2.279077
# iteration 400 / 1500: loss 2.286930
# iteration 500 / 1500: loss 2.291593
# iteration 600 / 1500: loss 2.275682
# iteration 700 / 1500: loss 2.285249
# iteration 800 / 1500: loss 2.286961
# iteration 900 / 1500: loss 2.288354
# iteration 1000 / 1500: loss 2.283625
# iteration 1100 / 1500: loss 2.286875
# iteration 1200 / 1500: loss 2.287101
# iteration 1300 / 1500: loss 2.289624
# iteration 1400 / 1500: loss 2.288338
# iteration 0 / 1500: loss 96.505090
# iteration 100 / 1500: loss 84.379316
# iteration 200 / 1500: loss 74.847118
# iteration 300 / 1500: loss 66.188512
# iteration 400 / 1500: loss 58.878251
# iteration 500 / 1500: loss 52.301807
# iteration 600 / 1500: loss 46.542803
# iteration 700 / 1500: loss 41.470516
# iteration 800 / 1500: loss 36.834999
# iteration 900 / 1500: loss 32.862154
# iteration 1000 / 1500: loss 29.191286
# iteration 1100 / 1500: loss 26.175800
# iteration 1200 / 1500: loss 23.206103
# iteration 1300 / 1500: loss 20.873698
# iteration 1400 / 1500: loss 18.650188
# iteration 0 / 1500: loss 779.387130
# iteration 100 / 1500: loss inf
# iteration 200 / 1500: loss inf
# iteration 300 / 1500: loss inf
# iteration 400 / 1500: loss inf
# iteration 500 / 1500: loss inf
# iteration 600 / 1500: loss inf
# iteration 700 / 1500: loss inf
# iteration 800 / 1500: loss inf
# iteration 900 / 1500: loss inf
# iteration 1000 / 1500: loss inf
# iteration 1100 / 1500: loss inf
# iteration 1200 / 1500: loss inf
# iteration 1300 / 1500: loss inf
# iteration 1400 / 1500: loss inf
# iteration 0 / 1500: loss 1540.714050
# iteration 100 / 1500: loss inf
# iteration 200 / 1500: loss inf
# iteration 300 / 1500: loss inf
# iteration 400 / 1500: loss inf
# iteration 500 / 1500: loss inf
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# iteration 0 / 1500: loss 3068.096408
# iteration 100 / 1500: loss inf
# iteration 200 / 1500: loss inf
# iteration 300 / 1500: loss inf
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# iteration 0 / 1500: loss 30927.028259
# iteration 100 / 1500: loss inf
# iteration 200 / 1500: loss nan
# iteration 300 / 1500: loss nan
# iteration 400 / 1500: loss nan
# iteration 500 / 1500: loss nan
# iteration 600 / 1500: loss nan
# iteration 700 / 1500: loss nan
# iteration 800 / 1500: loss nan
# iteration 900 / 1500: loss nan
# iteration 1000 / 1500: loss nan
# iteration 1100 / 1500: loss nan
# iteration 1200 / 1500: loss nan
# iteration 1300 / 1500: loss nan
# iteration 1400 / 1500: loss nan
# iteration 0 / 1500: loss 99.362538
# iteration 100 / 1500: loss 30.267791
# iteration 200 / 1500: loss 40.064853
# iteration 300 / 1500: loss 17.588745
# iteration 400 / 1500: loss 23.346234
# iteration 500 / 1500: loss 28.647163
# iteration 600 / 1500: loss 35.105167
# iteration 700 / 1500: loss 40.694438
# iteration 800 / 1500: loss 26.417526
# iteration 900 / 1500: loss 31.544199
# iteration 1000 / 1500: loss 26.609151
# iteration 1100 / 1500: loss 32.851650
# iteration 1200 / 1500: loss 30.351091
# iteration 1300 / 1500: loss 29.984030
# iteration 1400 / 1500: loss 21.154593
# iteration 0 / 1500: loss 775.049920
# iteration 100 / 1500: loss 634.631498
# iteration 200 / 1500: loss 519.340178
# iteration 300 / 1500: loss 425.269451
# iteration 400 / 1500: loss 348.109952
# iteration 500 / 1500: loss 285.445928
# iteration 600 / 1500: loss 233.733226
# iteration 700 / 1500: loss 191.553372
# iteration 800 / 1500: loss 157.217070
# iteration 900 / 1500: loss 129.081375
# iteration 1000 / 1500: loss 105.885432
# iteration 1100 / 1500: loss 86.955871
# iteration 1200 / 1500: loss 71.508628
# iteration 1300 / 1500: loss 59.031212
# iteration 1400 / 1500: loss 48.609649
# iteration 0 / 1500: loss 1532.646056
# iteration 100 / 1500: loss 1026.815859
# iteration 200 / 1500: loss 688.545886
# iteration 300 / 1500: loss 461.726574
# iteration 400 / 1500: loss 309.950737
# iteration 500 / 1500: loss 208.210428
# iteration 600 / 1500: loss 140.127890
# iteration 700 / 1500: loss 94.486609
# iteration 800 / 1500: loss 64.053582
# iteration 900 / 1500: loss 43.608645
# iteration 1000 / 1500: loss 29.885029
# iteration 1100 / 1500: loss 20.699075
# iteration 1200 / 1500: loss 14.607578
# iteration 1300 / 1500: loss 10.500820
# iteration 1400 / 1500: loss 7.733310
# iteration 0 / 1500: loss 3153.407534
# iteration 100 / 1500: loss 1415.002665
# iteration 200 / 1500: loss 635.302147
# iteration 300 / 1500: loss 285.927524
# iteration 400 / 1500: loss 129.375180
# iteration 500 / 1500: loss 59.275593
# iteration 600 / 1500: loss 27.773830
# iteration 700 / 1500: loss 13.632385
# iteration 800 / 1500: loss 7.293191
# iteration 900 / 1500: loss 4.506687
# iteration 1000 / 1500: loss 3.231805
# iteration 1100 / 1500: loss 2.695001
# iteration 1200 / 1500: loss 2.363810
# iteration 1300 / 1500: loss 2.314445
# iteration 1400 / 1500: loss 2.257779
# iteration 0 / 1500: loss 30734.399765
# iteration 100 / 1500: loss 11.009814
# iteration 200 / 1500: loss 2.287954
# iteration 300 / 1500: loss 2.286456
# iteration 400 / 1500: loss 2.281850
# iteration 500 / 1500: loss 2.286799
# iteration 600 / 1500: loss 2.288245
# iteration 700 / 1500: loss 2.284996
# iteration 800 / 1500: loss 2.289051
# iteration 900 / 1500: loss 2.279601
# iteration 1000 / 1500: loss 2.278826
# iteration 1100 / 1500: loss 2.275817
# iteration 1200 / 1500: loss 2.279550
# iteration 1300 / 1500: loss 2.280969
# iteration 1400 / 1500: loss 2.287657
# iteration 0 / 1500: loss 98.373622
# iteration 100 / 1500: loss 95.404905
# iteration 200 / 1500: loss 93.082768
# iteration 300 / 1500: loss 90.135848
# iteration 400 / 1500: loss 87.719539
# iteration 500 / 1500: loss 85.972150
# iteration 600 / 1500: loss 83.907650
# iteration 700 / 1500: loss 81.736961
# iteration 800 / 1500: loss 79.795450
# iteration 900 / 1500: loss 77.670343
# iteration 1000 / 1500: loss 76.079036
# iteration 1100 / 1500: loss 74.010643
# iteration 1200 / 1500: loss 72.446188
# iteration 1300 / 1500: loss 70.651400
# iteration 1400 / 1500: loss 68.802958
# iteration 0 / 1500: loss 779.620602
# iteration 100 / 1500: loss 39.635293
# iteration 200 / 1500: loss 3.912699
# iteration 300 / 1500: loss 2.130685
# iteration 400 / 1500: loss 2.117870
# iteration 500 / 1500: loss 2.077098
# iteration 600 / 1500: loss 2.061281
# iteration 700 / 1500: loss 2.133471
# iteration 800 / 1500: loss 2.119829
# iteration 900 / 1500: loss 2.061690
# iteration 1000 / 1500: loss 2.072239
# iteration 1100 / 1500: loss 2.096326
# iteration 1200 / 1500: loss 2.043737
# iteration 1300 / 1500: loss 2.114932
# iteration 1400 / 1500: loss 2.043067
# iteration 0 / 1500: loss 1541.220127
# iteration 100 / 1500: loss 5.536574
# iteration 200 / 1500: loss 2.145977
# iteration 300 / 1500: loss 2.176805
# iteration 400 / 1500: loss 2.126902
# iteration 500 / 1500: loss 2.101751
# iteration 600 / 1500: loss 2.146869
# iteration 700 / 1500: loss 2.155776
# iteration 800 / 1500: loss 2.174874
# iteration 900 / 1500: loss 2.146763
# iteration 1000 / 1500: loss 2.191047
# iteration 1100 / 1500: loss 2.156277
# iteration 1200 / 1500: loss 2.132800
# iteration 1300 / 1500: loss 2.150268
# iteration 1400 / 1500: loss 2.106212
# iteration 0 / 1500: loss 3039.825035
# iteration 100 / 1500: loss 2.200487
# iteration 200 / 1500: loss 2.208622
# iteration 300 / 1500: loss 2.206863
# iteration 400 / 1500: loss 2.220985
# iteration 500 / 1500: loss 2.170311
# iteration 600 / 1500: loss 2.178271
# iteration 700 / 1500: loss 2.174688
# iteration 800 / 1500: loss 2.222424
# iteration 900 / 1500: loss 2.181641
# iteration 1000 / 1500: loss 2.190189
# iteration 1100 / 1500: loss 2.156413
# iteration 1200 / 1500: loss 2.192010
# iteration 1300 / 1500: loss 2.189282
# iteration 1400 / 1500: loss 2.175920
# iteration 0 / 1500: loss 30648.810083
# iteration 100 / 1500: loss 2.281439
# iteration 200 / 1500: loss 2.279710
# iteration 300 / 1500: loss 2.295445
# iteration 400 / 1500: loss 2.298062
# iteration 500 / 1500: loss 2.292627
# iteration 600 / 1500: loss 2.296417
# iteration 700 / 1500: loss 2.293111
# iteration 800 / 1500: loss 2.286343
# iteration 900 / 1500: loss 2.297105
# iteration 1000 / 1500: loss 2.288646
# iteration 1100 / 1500: loss 2.292299
# iteration 1200 / 1500: loss 2.293766
# iteration 1300 / 1500: loss 2.296493
# iteration 1400 / 1500: loss 2.284476
# iteration 0 / 1500: loss 98.179475
# iteration 100 / 1500: loss 66.821212
# iteration 200 / 1500: loss 47.039384
# iteration 300 / 1500: loss 33.121480
# iteration 400 / 1500: loss 23.576940
# iteration 500 / 1500: loss 16.984605
# iteration 600 / 1500: loss 12.303237
# iteration 700 / 1500: loss 9.100307
# iteration 800 / 1500: loss 6.864330
# iteration 900 / 1500: loss 5.412630
# iteration 1000 / 1500: loss 4.315360
# iteration 1100 / 1500: loss 3.565832
# iteration 1200 / 1500: loss 3.164389
# iteration 1300 / 1500: loss 2.752457
# iteration 1400 / 1500: loss 2.456304
# iteration 0 / 1500: loss 774.014039
# iteration 100 / 1500: loss 346.820589
# iteration 200 / 1500: loss 156.296819
# iteration 300 / 1500: loss 71.123235
# iteration 400 / 1500: loss 32.967330
# iteration 500 / 1500: loss 15.932961
# iteration 600 / 1500: loss 8.302796
# iteration 700 / 1500: loss 4.860632
# iteration 800 / 1500: loss 3.372157
# iteration 900 / 1500: loss 2.646890
# iteration 1000 / 1500: loss 2.304883
# iteration 1100 / 1500: loss 2.185365
# iteration 1200 / 1500: loss 2.133309
# iteration 1300 / 1500: loss 2.081952
# iteration 1400 / 1500: loss 2.153110
# iteration 0 / 1500: loss 1538.075843
# iteration 100 / 1500: loss 309.230036
# iteration 200 / 1500: loss 63.578290
# iteration 300 / 1500: loss 14.422221
# iteration 400 / 1500: loss 4.598147
# iteration 500 / 1500: loss 2.634632
# iteration 600 / 1500: loss 2.271756
# iteration 700 / 1500: loss 2.118946
# iteration 800 / 1500: loss 2.165308
# iteration 900 / 1500: loss 2.089776
# iteration 1000 / 1500: loss 2.132293
# iteration 1100 / 1500: loss 2.151152
# iteration 1200 / 1500: loss 2.151820
# iteration 1300 / 1500: loss 2.154164
# iteration 1400 / 1500: loss 2.155490
# iteration 0 / 1500: loss 3000.664932
# iteration 100 / 1500: loss 121.020527
# iteration 200 / 1500: loss 6.897331
# iteration 300 / 1500: loss 2.401932
# iteration 400 / 1500: loss 2.221041
# iteration 500 / 1500: loss 2.174306
# iteration 600 / 1500: loss 2.212915
# iteration 700 / 1500: loss 2.176998
# iteration 800 / 1500: loss 2.203374
# iteration 900 / 1500: loss 2.167305
# iteration 1000 / 1500: loss 2.171305
# iteration 1100 / 1500: loss 2.219547
# iteration 1200 / 1500: loss 2.165796
# iteration 1300 / 1500: loss 2.181456
# iteration 1400 / 1500: loss 2.176749
# iteration 0 / 1500: loss 30686.055864
# iteration 100 / 1500: loss 2.287813
# iteration 200 / 1500: loss 2.284969
# iteration 300 / 1500: loss 2.284301
# iteration 400 / 1500: loss 2.284948
# iteration 500 / 1500: loss 2.276862
# iteration 600 / 1500: loss 2.279935
# iteration 700 / 1500: loss 2.283305
# iteration 800 / 1500: loss 2.291550
# iteration 900 / 1500: loss 2.287043
# iteration 1000 / 1500: loss 2.286141
# iteration 1100 / 1500: loss 2.288829
# iteration 1200 / 1500: loss 2.290863
# iteration 1300 / 1500: loss 2.288088
# iteration 1400 / 1500: loss 2.290531
# iteration 0 / 1500: loss 96.957328
# iteration 100 / 1500: loss 86.170522
# iteration 200 / 1500: loss 77.806410
# iteration 300 / 1500: loss 70.909369
# iteration 400 / 1500: loss 64.329946
# iteration 500 / 1500: loss 58.620720
# iteration 600 / 1500: loss 53.101059
# iteration 700 / 1500: loss 48.544469
# iteration 800 / 1500: loss 44.226884
# iteration 900 / 1500: loss 40.216665
# iteration 1000 / 1500: loss 36.493286
# iteration 1100 / 1500: loss 33.449164
# iteration 1200 / 1500: loss 30.496098
# iteration 1300 / 1500: loss 27.924419
# iteration 1400 / 1500: loss 25.457868
# lr 2.000000e-08 reg 3.000000e+03 train accuracy: 0.194816 val accuracy: 0.213000
# lr 2.000000e-08 reg 2.500000e+04 train accuracy: 0.245367 val accuracy: 0.249000
# lr 2.000000e-08 reg 5.000000e+04 train accuracy: 0.295776 val accuracy: 0.311000
# lr 2.000000e-08 reg 1.000000e+05 train accuracy: 0.282837 val accuracy: 0.290000
# lr 2.000000e-08 reg 1.000000e+06 train accuracy: 0.259551 val accuracy: 0.278000
# lr 8.000000e-08 reg 3.000000e+03 train accuracy: 0.290633 val accuracy: 0.281000
# lr 8.000000e-08 reg 2.500000e+04 train accuracy: 0.327612 val accuracy: 0.350000
# lr 8.000000e-08 reg 5.000000e+04 train accuracy: 0.305510 val accuracy: 0.326000
# lr 8.000000e-08 reg 1.000000e+05 train accuracy: 0.285694 val accuracy: 0.300000
# lr 8.000000e-08 reg 1.000000e+06 train accuracy: 0.247837 val accuracy: 0.259000
# lr 1.000000e-07 reg 3.000000e+03 train accuracy: 0.302755 val accuracy: 0.329000
# lr 1.000000e-07 reg 2.500000e+04 train accuracy: 0.331878 val accuracy: 0.346000
# lr 1.000000e-07 reg 5.000000e+04 train accuracy: 0.307898 val accuracy: 0.324000
# lr 1.000000e-07 reg 1.000000e+05 train accuracy: 0.285490 val accuracy: 0.299000
# lr 1.000000e-07 reg 1.000000e+06 train accuracy: 0.248776 val accuracy: 0.258000
# lr 3.000000e-07 reg 3.000000e+03 train accuracy: 0.382367 val accuracy: 0.390000
# lr 3.000000e-07 reg 2.500000e+04 train accuracy: 0.329776 val accuracy: 0.335000
# lr 3.000000e-07 reg 5.000000e+04 train accuracy: 0.299980 val accuracy: 0.304000
# lr 3.000000e-07 reg 1.000000e+05 train accuracy: 0.305204 val accuracy: 0.310000
# lr 3.000000e-07 reg 1.000000e+06 train accuracy: 0.254061 val accuracy: 0.245000
# lr 5.000000e-05 reg 3.000000e+03 train accuracy: 0.156367 val accuracy: 0.170000
# lr 5.000000e-05 reg 2.500000e+04 train accuracy: 0.051837 val accuracy: 0.043000
# lr 5.000000e-05 reg 5.000000e+04 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 1.000000e+05 train accuracy: 0.100265 val accuracy: 0.087000
# lr 5.000000e-05 reg 1.000000e+06 train accuracy: 0.100265 val accuracy: 0.087000
# best validation accuracy achieved during cross-validation: 0.390000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.385000

# %% [markdown]
# **Inline Question 2** - *True or False*
#
# Suppose the overall training loss is defined as the sum of the per-datapoint loss over all training examples. It is possible to add a new datapoint to a training set that would leave the SVM loss unchanged, but this is not the case with the Softmax classifier loss.
#
# $\color{blue}{\textit Your Answer:}$
#
#
# $\color{blue}{\textit Your Explanation:}$

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
    plt.subplot(2, 5, i + 1)
    
    # Rescale the weights to be between 0 and 255
    wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
    plt.imshow(wimg.astype('uint8'))
    plt.axis('off')
    plt.title(classes[i])
